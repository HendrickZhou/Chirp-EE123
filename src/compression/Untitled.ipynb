# %%
import sys
import os
script_path = os.path.abspath('')
module_path = script_path[:script_path.rfind('src')]+ 'src' + '/'
asset_path = script_path[:script_path.rfind('src')]+ 'asset' + '/'
sys.path.append(module_path)
import numpy as np
import matplotlib.pyplot as plt
import pca

from utils.Helper_functions import *

image_stack = imageStack_load(asset_path+"dog.png")

pca_example=pca.PCA(image_stack)
pca_example.procInput_noFlatten()
compressedX,param=pca_example.getArraysToTransmit()

reconstructed=pca.pca_reconstruct(np.around(compressedX, decimals = 0),param)

print(len(compressedX))
# print(param)

print(reconstructed.shape)
# Out:
# 252380
# (6, 260, 500, 3)

# %%
npArray_play(reconstructed)
# Out:
#   <div class="bk-root" id="5688a510-dd1c-4ac3-bf18-04873ed67c5f"></div>
